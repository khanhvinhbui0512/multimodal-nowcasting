# %%
# from subprocess import Popen
# from getpass import getpass
# import platform
# import os
# import shutil

# urs = 'urs.earthdata.nasa.gov'    # Earthdata URL to call for authentication
# prompts = ['Enter NASA Earthdata Login Username \n(or create an account at urs.earthdata.nasa.gov): ',
#            'Enter NASA Earthdata Login Password: ']

# homeDir = os.path.expanduser("~") + os.sep

# with open(homeDir + '.netrc', 'w') as file:
#     file.write('machine {} login {} password {}'.format(urs, getpass(prompt=prompts[0]), getpass(prompt=prompts[1])))
#     file.close()
# with open(homeDir + '.urs_cookies', 'w') as file:
#     file.write('')
#     file.close()
# with open(homeDir + '.dodsrc', 'w') as file:
#     file.write('HTTP.COOKIEJAR={}.urs_cookies\n'.format(homeDir))
#     file.write('HTTP.NETRC={}.netrc'.format(homeDir))
#     file.close()

# print('Saved .netrc, .urs_cookies, and .dodsrc to:', homeDir)

# # Set appropriate permissions for Linux/macOS
# if platform.system() != "Windows":
#     Popen('chmod og-rw ~/.netrc', shell=True)
# else:
#     # Copy dodsrc to working directory in Windows  
#     shutil.copy2(homeDir + '.dodsrc', os.getcwd())
#     print('Copied .dodsrc to:', os.getcwd())
# Out:
# Saved .netrc, .urs_cookies, and .dodsrc to: /Users/tuphamminh/

# %%
# !chmod 0600 ~/temp.netrc

# %%
# cd download
# Out:
# /Users/tuphamminh/download

# %%
# !wget --load-cookies ~/temp.urs_cookies --save-cookies ~/temp.urs_cookies --keep-session-cookies -i /Users/tuphamminh/Downloads/text.txt
# Out:
# --2024-02-14 20:52:35--  https://arthurhou.pps.eosdis.nasa.gov/Documents/IMERG_V07_ATBD_final.pdf
# Resolving arthurhou.pps.eosdis.nasa.gov (arthurhou.pps.eosdis.nasa.gov)... 2001:4d0:241a:40a0::64, 198.118.195.100
# Connecting to arthurhou.pps.eosdis.nasa.gov (arthurhou.pps.eosdis.nasa.gov)|2001:4d0:241a:40a0::64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3526898 (3.4M) [application/pdf]
# Saving to: ‘IMERG_V07_ATBD_final.pdf.4’
#
# IMERG_V07_ATBD_fina 100%[===================>]   3.36M  1.05MB/s    in 3.2s
#
# 2024-02-14 20:52:40 (1.05 MB/s) - ‘IMERG_V07_ATBD_final.pdf.4’ saved [3526898/3526898]
#
# --2024-02-14 20:52:40--  https://gpm1.gesdisc.eosdis.nasa.gov/opendap/GPM_L3/GPM_3IMERGHH.07/2023/152/3B-HHR.MS.MRG.3IMERG.20230601-S000000-E002959.0000.V07B.HDF5.nc4?precipitation[0:0][2830:2900][979:1039],time,lon[2830:2900],lat[979:1039]
# ...

# %%
from pydap.client import open_url
from pydap.cas.urs import setup_session
import requests

dataset_url = '/Users/tuphamminh/Downloads/text.txt'

# username = 'tuut'
# password = 'VgBGjjq!G7zu$5$'

# f = open(dataset_url, "r")
# for x in f:
#     result = requests.get(x)
#     try:
#         result.raise_for_status()
#     except:
#         print('requests.get() returned an error code '+str(result.status_code))
        
import webbrowser
with open(dataset_url,"r") as f:
    for url in f:
        webbrowser.open_new_tab(url)

# %%
# !ls
# Out:
# IMERG_V07_ATBD_final.pdf   IMERG_V07_ATBD_final.pdf.2
# IMERG_V07_ATBD_final.pdf.1
