# %%
import xarray as xr


# z500 = xr.open_mfdataset('/Users/tuphamminh/Downloads/2023.nc')
z500 = xr.open_mfdataset('/Users/tuphamminh/Downloads/constants_5.625deg.nc')
z500
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 32, lon: 64)
# Coordinates:
#   * lat        (lat) float64 -87.19 -81.56 -75.94 -70.31 ... 75.94 81.56 87.19
#   * lon        (lon) float64 0.0 5.625 11.25 16.88 ... 337.5 343.1 348.8 354.4
# Data variables:
#     orography  (lat, lon) float32 dask.array<chunksize=(32, 64), meta=np.ndarray>
#     lsm        (lat, lon) float32 dask.array<chunksize=(32, 64), meta=np.ndarray>
#     slt        (lat, lon) float32 dask.array<chunksize=(32, 64), meta=np.ndarray>
#     lat2d      (lat, lon) float64 dask.array<chunksize=(32, 64), meta=np.ndarray>
#     lon2d      (lat, lon) float64 dask.array<chunksize=(32, 64), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2019-11-21 15:25:20 GMT by grib_to_netcdf-2.14.0: /opt/ecmw...

# %%
z500.lat2d.plot()

# %%
z500.tp[0].plot()

# %%
LatIndexer, LonIndexer = 'latitude', 'longitude'
SliceData = z500.loc[{LonIndexer: slice(104.25, 109.25),LatIndexer: slice(13, 8.25)}]
SliceData
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 21, latitude: 20, time: 8760)
# Coordinates:
#   * longitude  (longitude) float32 104.2 104.5 104.8 105.0 ... 108.8 109.0 109.2
#   * latitude   (latitude) float32 13.0 12.75 12.5 12.25 ... 9.0 8.75 8.5 8.25
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-12-31T23:00:00
# Data variables:
#     tp         (time, latitude, longitude) float32 dask.array<chunksize=(8760, 20, 21), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-10 06:14:32 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
SliceData["tp"][0].plot()
